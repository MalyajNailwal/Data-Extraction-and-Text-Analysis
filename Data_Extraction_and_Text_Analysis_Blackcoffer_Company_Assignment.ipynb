# %%
#importing library
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
from google.colab import files
import nltk
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#importing input file
df = pd.read_excel('/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/Input.xlsx')[['URL_ID','URL']]

# %%
df=df.iloc[0:115]

# %%
df
# Out:
#       URL_ID                                                URL
# 0      123.0  https://insights.blackcoffer.com/rise-of-telem...
# 1      321.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 2     2345.0  https://insights.blackcoffer.com/rise-of-e-hea...
# 3     4321.0  https://insights.blackcoffer.com/rise-of-telem...
# 4      432.0  https://insights.blackcoffer.com/rise-of-telem...
# ..       ...                                                ...
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
# [114 rows x 2 columns]

# %%
df.drop('URL_ID',axis=1,inplace=True)

# %% [markdown]
# Data extraction

# %%
# Importing necessary libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import os  # Import the 'os' module for creating folders
from google.colab import files
import nltk
import string
nltk.download('punkt')


# Specify the folder path
output_folder = '/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/TitleText'

# Check if the folder already exists
if not os.path.exists(output_folder):
    # If it doesn't exist, create the folder
    os.makedirs(output_folder)
    print(f"Folder '{output_folder}' created successfully.")

url_id = 1
for i in range(0, len(df)):
    j = df.iloc[i].values

    # Set up headers to mimic a web browser
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'}

    # Make a request to the URL
    page = requests.get(j[0], headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Extract content from the web page
    content = soup.findAll(attrs={'class': 'td-post-content'})

    # Check if content is not empty before accessing its index
    if content:
        content = content[0].text.replace('\xa0', "  ").replace('\n', "  ")
    else:
        content = ""  # Set content to an empty string if it's empty

    # Extract title from the web page
    title = soup.findAll(attrs={'class': 'entry-title'})

    # Check if title is not empty before accessing its index
    if title:
        title = title[16].text.replace('\n', "  ").replace('/', "")
    else:
        title = ""  # Set title to an empty string if it's empty

    # Combine title and content
    text = title + '.' + content
    text = np.array(text)
    text.reshape(1, -1)
    df1 = pd.Series(text)

    # Create the file path for saving the text file
    b = os.path.join(output_folder, f"{url_id}.txt")

    with open(b, 'a') as f:  # Creating and writing to the text file
        df1.to_csv(f, line_terminator=',', index=False, header=False)
        # Uncomment the line below to download the text file (commented out to avoid potential issues)
        # files.download(b)

    url_id += 1  # Increment the URL ID for the next iteration
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <ipython-input-6-1adec3d4d750>:61: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   df1.to_csv(f, line_terminator=',', index=False, header=False)

# %% [markdown]
# Data analysis

# %%
#importing each extracted files
text=pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/TitleText/114.txt",header=None)

# %%
#information of data frame
text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1 non-null      object
#  1   1       1 non-null      object
#  2   2       1 non-null      object
#  3   3       0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 160.0+ bytes

# %%
# Check the number of columns in the DataFrame
num_columns = len(text.columns)

# Drop the extra column if there is more than one column
if num_columns > 1:
    text.drop(1, axis=1, inplace=True)
else:
    # If there's only one column, drop it without specifying the label
    text.drop(text.columns[0], axis=1, inplace=True)

# %%
#converting type
text=text.astype(str)

# %%
#converting text to sentence
import re
a=text[0].str.split('([\.]\s)',expand=False)#splitting text on '.'
b=a.explode()#converting to rows
b=pd.DataFrame(b)#creating data frame
b.columns=['abc']

# %%
#removing . char from each rows
def abcd(x):
    nopunc =[char for char in x if char != '.']
    return ''.join(nopunc)
b['abc']=b['abc'].apply(abcd)

# %%
#replacing emty space with null values
c=b.replace('',np.nan,regex=True)
c=c.mask(c==" ")
c=c.dropna()
c.reset_index(drop=True,inplace=True)

# %%
c
# Out:
#                                                   abc
# 0                 Continued Demand for Sustainability
# 1    The business of business is no longer to do j...
# 2   Rather, the concept  of business is moving tow...
# 3   People, planet, and profits are the core  ideo...
# 4   Sustainability is taken  into account when com...
# 5   As corporate  accountability rises, expectatio...
# 6     Business  globalization that has happened ov...
# 7    Unfortunately for them, their horrible past h...
# 8   With the emergence of internet and  social med...
# 9   The media is fast  picking up on cover-ups, ha...
# 10  Therefore to survive, companies  are compelled...
# 11    Many  of the irresponsible company practices...
# 12  For instance, deferred maintenance and slack l...
# 13  Estimates placed more than half a million casu...
# 14  Finally, Union Carbide Corporation’s 1989 liti...
# 15  Another  example where the company was forced ...
# 16  The local communities faced acute water  short...
# 17  These businesses stated above didn’t  respect ...
# 18   Today’s  issues cannot be solved without part...
# 19  They need to  engage with regulators, communit...
# 20  Issues where engagement are required include  ...
# 21   By actively pursuing the triple  bottom line,...
# 22  Sometimes, there is a divergence between the t...
# 23  For example, Toyota is well known for hybrid e...
# 24  Toyota decreased its dependence on imports and...
# 25  Recent reports show that investors are shying ...
# 26  Reactive to proactive: As a result of a crisis...
# 27  For instance, in locations like Indonesia thro...
# 28  It became a pioneer in the establishment of tr...
# 29  It also recognized huge problems, especially i...
# 30  These businesses have all created more proacti...
# 31   Quantify,  including the company situation:  ...
# 32  This is a straightforward problem with respect...
# 33    Transparency  is a precondition for assessin...
# 34  The only way for companies to achieve transpar...
# 35   Sustainability -triple bottom line- can drive...
# 36  Several investors today use ESG metrics to eva...
# 37  Investors are looking at variables like the ca...
# 38  Companies have started responding to investors...
# 39  Research indicates that businesses with elevat...
# 40  It’s only a matter of time, the flow of sustai...
# 41   Blackcoffer Insights 12 | Sanjana Jose Varghe...

# %%
#importing nltk library and stopwords
import nltk
import string

# %%
punc=[punc for punc in string.punctuation]

# %%
punc
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
# Importing stop words files that are provided
StopWords_Auditor = pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/StopWords/StopWords_Auditor.txt", header=None)
StopWords_Currencies = pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/StopWords/StopWords_Currencies.txt", header=None, encoding="ISO-8859-1", sep='\t')
StopWords_DatesandNumbers = pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/StopWords/StopWords_DatesandNumbers.txt", header=None)
StopWords_Generic = pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/StopWords/StopWords_Generic.txt", header=None)
StopWords_GenericLong = pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/StopWords/StopWords_GenericLong.txt", header=None)
StopWords_Geographic = pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/StopWords/StopWords_Geographic.txt", header=None)
StopWords_Names = pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/StopWords/StopWords_Names.txt", header=None)

# %%
#creating func for removing stop words
def text_process(text):
    nopunc =[char for char in text if char not in punc or char not in [':',',','(',')','’','?']]
    nopunc=''.join(nopunc)
    txt=' '.join([word for word in nopunc.split() if word.lower() not in StopWords_Auditor])
    txt1=' '.join([word for word in txt.split() if word.lower() not in StopWords_Currencies])
    txt2=' '.join([word for word in txt1.split() if word.lower() not in StopWords_DatesandNumbers])
    txt3=' '.join([word for word in txt2.split() if word.lower() not in StopWords_Generic])
    txt4=' '.join([word for word in txt3.split() if word.lower() not in StopWords_GenericLong])
    txt5=' '.join([word for word in txt4.split() if word.lower() not in StopWords_Geographic])
    return ' '.join([word for word in txt5.split() if word.lower() not in StopWords_Names])

# %%
#applying func for each row
c['abc']=c['abc'].apply(text_process)

# %%
c
# Out:
#                                                   abc
# 0                 Continued Demand for Sustainability
# 1   The business of business is no longer to do ju...
# 2   Rather the concept of business is moving towar...
# 3   People planet and profits are the core ideolog...
# 4   Sustainability is taken into account when comp...
# 5   As corporate accountability rises expectations...
# 6   Business globalization that has happened over ...
# 7   Unfortunately for them their horrible past has...
# 8   With the emergence of internet and social medi...
# 9   The media is fast picking up on cover-ups half...
# 10  Therefore to survive companies are compelled t...
# 11  Many of the irresponsible company practices an...
# 12  For instance deferred maintenance and slack le...
# 13  Estimates placed more than half a million casu...
# 14  Finally Union Carbide Corporation’s 1989 litig...
# 15  Another example where the company was forced t...
# 16  The local communities faced acute water shorta...
# 17  These businesses stated above didn’t respect s...
# 18  Today’s issues cannot be solved without partic...
# 19  They need to engage with regulators communitie...
# 20  Issues where engagement are required include p...
# 21  By actively pursuing the triple bottom line th...
# 22  Sometimes there is a divergence between the tw...
# 23  For example Toyota is well known for hybrid en...
# 24  Toyota decreased its dependence on imports and...
# 25  Recent reports show that investors are shying ...
# 26  Reactive to proactive As a result of a crisis ...
# 27  For instance in locations like Indonesia throu...
# 28  It became a pioneer in the establishment of tr...
# 29  It also recognized huge problems especially in...
# 30  These businesses have all created more proacti...
# 31  Quantify including the company situation all b...
# 32  This is a straightforward problem with respect...
# 33  Transparency is a precondition for assessing a...
# 34  The only way for companies to achieve transpar...
# 35  Sustainability -triple bottom line- can drive ...
# 36  Several investors today use ESG metrics to eva...
# 37  Investors are looking at variables like the ca...
# 38  Companies have started responding to investors...
# 39  Research indicates that businesses with elevat...
# 40  It’s only a matter of time the flow of sustain...
# 41  Blackcoffer Insights 12 | Sanjana Jose Varghes...

# %%
# Importing master Dictionary
positive = pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/MasterDictionary/negative-words.txt", header=None, encoding="ISO-8859-1", sep='\t')
negative = pd.read_csv("/content/drive/MyDrive/Data_Extraction_and_Text_Analysis_Blackcoffer_Company_Assignment/MasterDictionary/positive-words.txt", header=None, encoding="ISO-8859-1", sep='\t')

# %%
positive.columns=['abc']
negative.columns=['abc']
positive['abc']=positive['abc'].astype(str)
negative['abc']=negative['abc'].astype(str)

# %%
#positive and negative dictionary without stopwords
positive['abc']=positive['abc'].apply(text_process)
negative['abc']=negative['abc'].apply(text_process)

# %%
#negative list
length=negative.shape[0]
neg=[]
for i in range(0,length):
  nopunc =[char for char in negative.iloc[i] if char not in string.punctuation or char != '+']
  nopunc=''.join(nopunc)
  neg.append(nopunc)

# %%
#positive list
length=positive.shape[0]
post=[]
for i in range(0,length):
   nopunc =[char for char in positive.iloc[i] if char not in string.punctuation or char != '+']
   nopunc=''.join(nopunc)

   post.append(nopunc)

# %%
#importing tokenize library
from nltk.tokenize import word_tokenize

# %%
txt_list=[]
length=c.shape[0]
for i in range(0,length):
  txt=' '.join([word for word in c.iloc[i]])
  txt_list.append(txt)

# %%
#tokenization of text
tokenize_text=[]
for i in txt_list:

  tokenize_text+=(word_tokenize(i))

# %%
print(tokenize_text)
# Out:
# ['Continued', 'Demand', 'for', 'Sustainability', 'The', 'business', 'of', 'business', 'is', 'no', 'longer', 'to', 'do', 'just', 'business', 'or', 'increase', 'the', 'bottom', 'line', 'to', 'maximize', 'shareholder', 'value', 'Rather', 'the', 'concept', 'of', 'business', 'is', 'moving', 'towards', 'a', 'new', 'dimension', 'of', 'sustainable', 'business', 'the', 'triple', 'bottom', 'line', 'People', 'planet', 'and', 'profits', 'are', 'the', 'core', 'ideologies', 'that', 'are', 'rooted', 'in', 'sustainable', 'business', 'Sustainability', 'is', 'taken', 'into', 'account', 'when', 'companies', 'want', 'to', 'create', 'long-term', 'value', 'creation', 'along', 'with', 'strategies', 'that', 'promote', 'the', 'longevity', 'of', 'the', 'company', 'As', 'corporate', 'accountability', 'rises', 'expectations', 'and', 'need', 'for', 'transparency', 'among', 'stakeholders', 'increases', 'therefore', 'companies', 'have', 'started', 'to', 'recognize', 'the', 'need', 'to', 'be', 'sustainable', 'to', 'stay', 'alert', 'and', 'alive', 'Business', 'globalization', 'that', 'has', 'happened', 'over', 'the', 'previous', 'few', 'decades', 'has', 'made', 'some', 'companies', 'more', 'powerful', 'than', 'some', 'national', 'governments', 'making', 'it', 'easy', 'for', 'them', 'to', 'exploit', 'inexpensive', 'labor', 'plunder', 'natural', 'resources', 'causing', 'severe', 'impacts', 'through', 'pollution', 'on', 'the', 'natural', 'environment', 'human', 'health', 'and', 'biodiversity', 'Unfortunately', 'for', 'them', 'their', 'horrible', 'past', 'has', 'been', 'catching', 'up', 'with', 'them', 'like', 'in', 'the', 'case', 'of', 'child', 'labor', 'issues', 'of', 'IKEA', '&', 'Nike', 'Rana', 'Plaza', 'accident', 'in', 'Bangladesh', 'affecting', 'Zara', 'H', '&', 'M', 'and', 'other', 'clothing', 'brands', 'environment', 'pollution', 'by', 'BP', 'Shell', 'Exxon', 'Mobil', 'etc', 'With', 'the', 'emergence', 'of', 'internet', 'and', 'social', 'media', 'these', 'practices', 'can', 'no', 'longer', 'be', 'covered', 'up', 'and', 'silenced', 'the', 'world', 'has', 'become', 'more', 'educated', 'and', 'less', 'tolerant', 'and', 'therefore', 'with', 'every', 'misdemeanor', 'that', 'is', 'committed', 'brand', 'equity', 'takes', 'a', 'hit', 'The', 'media', 'is', 'fast', 'picking', 'up', 'on', 'cover-ups', 'half-truths', 'and', 'bad', 'corporate', 'behavior', 'and', 'demanding', 'accountability', 'and', 'transparency', 'from', 'corporates', 'Therefore', 'to', 'survive', 'companies', 'are', 'compelled', 'to', 'adopt', 'sustainability', 'and', 'bring', 'forth', 'the', 'rules', 'for', 'their', 'suppliers', 'as', 'well', 'Many', 'of', 'the', 'irresponsible', 'company', 'practices', 'and', 'disasters', 'that', 'are', 'witnessed', 'in', 'that', 'last', 'couple', 'of', 'decades', 'were', 'motivated', 'solely', 'by', 'short-termism-', 'the', 'desire', 'for', 'instant', 'gratification-', 'and', 'the', 'appeal', 'of', 'short-term', 'performance', 'incentives', 'For', 'instance', 'deferred', 'maintenance', 'and', 'slack', 'leadership', 'were', 'to', 'blame', 'for', 'the', '1984', 'leaks', 'from', 'the', 'pesticide', 'plant', 'Union', 'Carbide', 'India', 'Ltd', 'in', 'Bhopal', 'Estimates', 'placed', 'more', 'than', 'half', 'a', 'million', 'casualties', 'from', 'the', 'gas', 'discharge', 'of', 'the', 'plant', 'Finally', 'Union', 'Carbide', 'Corporation', '’', 's', '1989', 'litigation', 'payout', 'came', 'out', 'to', 'today', '’', 's', 'equivalent', 'of', 'nearly', 'one', 'billion', 'US', 'dollars', 'Another', 'example', 'where', 'the', 'company', 'was', 'forced', 'to', 'shut', 'down', 'operations', 'was', 'Coca', 'Cola', 'at', 'its', 'Plachimada', 'plant', 'in', 'Kerala', 'The', 'local', 'communities', 'faced', 'acute', 'water', 'shortage', 'after', 'the', 'commissioning', 'of', 'the', 'plant', 'and', 'the', 'company', 'authorities', 'blatantly', 'ignored', 'the', 'community', 'woes', 'These', 'businesses', 'stated', 'above', 'didn', '’', 't', 'respect', 'stakeholder', 'engagement', ...

# %%
len(tokenize_text)
# Out:
# 1032

# %% [markdown]
# 1.POSITIVE SCORE

# %%
positive_score=0
for i in tokenize_text:
  if(i.lower() in post):
    positive_score+=1
print('postive score=', positive_score)
# Out:
# postive score= 34

# %% [markdown]
# 2.NEGATIVE SCORE

# %%
negative_score=0
for i in tokenize_text:
  if(i.lower() in neg):
    negative_score+=1
print('negative score=', negative_score)
# Out:
# negative score= 58

# %% [markdown]
# 3.POLARITY SCORE

# %%
#Polarity Score = (Positive Score – Negative Score)/ ((Positive Score + Negative Score) + 0.000001)
Polarity_Score=(positive_score-negative_score)/((positive_score+negative_score)+0.000001)
print('polarity_score=', Polarity_Score)
# Out:
# polarity_score= -0.2608695623818526

# %% [markdown]
# 4.SUBJECTIVITY SCORE

# %%
#Subjectivity Score = (Positive Score + Negative Score)/ ((Total Words after cleaning) + 0.000001)
subjectiivity_score=(positive_score-negative_score)/((len(tokenize_text))+ 0.000001)
print('subjectivity_score',subjectiivity_score)
# Out:
# subjectivity_score -0.023255813930953665

# %% [markdown]
# 5.AVG SENTENCE LENGTH

# %%
length=c.shape[0]
avg_length=[]
for i in range(0,length):
  avg_length.append(len(c['abc'].iloc[i]))
avg_senetence_length=sum(avg_length)/len(avg_length)
print('avg sentence length=', avg_senetence_length)
# Out:
# avg sentence length= 162.38095238095238

# %% [markdown]
# 6.PERCENTAGE OF COMPLEX WORDS

# %%
vowels=['a','e','i','o','u']
import re
count=0
complex_Word_Count=0
for i in tokenize_text:
  x=re.compile('[es|ed]$')
  if x.match(i.lower()):
   count+=0
  else:
    for j in i:
      if(j.lower() in vowels ):
        count+=1
  if(count>2):
   complex_Word_Count+=1
  count=0

# %%
Percentage_of_Complex_words=complex_Word_Count/len(tokenize_text)
print('percentag of complex words= ',Percentage_of_Complex_words)
# Out:
# percentag of complex words=  0.35658914728682173

# %% [markdown]
# 7.FOG INDEX

# %%
#Fog Index = 0.4 * (Average Sentence Length + Percentage of Complex words)
Fog_Index = 0.4 * (avg_senetence_length + Percentage_of_Complex_words)
print('fog index= ',Fog_Index )
# Out:
# fog index=  65.09501661129569

# %% [markdown]
# 8.AVG NUMBER OF WORDS PER SENTENCE

# %%
length=c.shape[0]
avg_length=[]
for i in range(0,length):
  a=[word.split(' ') for word in c.iloc[i]]
  avg_length.append(len(a[0]))
  a=0
#avg
avg_no_of_words_per_sentence=sum(avg_length)/length
print("avg no of words per sentence= ",avg_no_of_words_per_sentence)
# Out:
# avg no of words per sentence=  23.80952380952381

# %% [markdown]
# 9.COMPLEX WORD COUNT

# %%
vowels = {'a', 'e', 'i', 'o', 'u'}
count = 0
complex_Word_Count = 0
for i in tokenize_text:
    x = re.compile('es$|ed$', re.IGNORECASE)
    if x.match(i):
        count += 0
    else:
        for j in i:
            if j.lower() in vowels:
                count += 1
        if count > 2:
            complex_Word_Count += 1
    count = 0

print('complex words count =', complex_Word_Count)
# Out:
# complex words count = 368

# %% [markdown]
# 10.WORD COUNT

# %%
word_count=len(tokenize_text)
print('word count= ', word_count)
# Out:
# word count=  1032

# %% [markdown]
# 11.SYLLABLE PER WORD

# %%
vowels=['a','e','i','o','u']
import re
count=0
for i in tokenize_text:
  x=re.compile('[es|ed]$')
  if x.match(i.lower()):
   count+=0
  else:
    for j in i:
      if(j.lower() in vowels ):
        count+=1
syllable_count=count
print('syllable_per_word= ',syllable_count)
# Out:
# syllable_per_word=  2254

# %% [markdown]
# 12.PERSONAL PRONOUNS

# %%
pronouns = ['i', 'we', 'my', 'ours', 'us']
count = 0

for word in tokenize_text:
    if word.lower() in pronouns:
        count += 1

personal_pronouns = count
print('personal pronouns =', personal_pronouns)
# Out:
# personal pronouns = 1

# %% [markdown]
# 13.AVG WORD LENGTH

# %%
count=0
for i in tokenize_text:
  for j in i:
    count+=1
avg_word_length=count/len(tokenize_text)
print('avg word= ', avg_word_length)
# Out:
# avg word=  5.680232558139535

# %%
data={'positive_score':positive_score,'negative_score':negative_score,'Polarity_Score':Polarity_Score,'subjectiivity_score':subjectiivity_score,'avg_senetence_length':avg_senetence_length,'Percentage_of_Complex_words':Percentage_of_Complex_words,'Fog_Index':Fog_Index,'avg_no_of_words_per_sentence':avg_no_of_words_per_sentence,'complex_Word_Count':complex_Word_Count,'word_count':word_count,'syllable_count':syllable_count,'personal_pronouns':personal_pronouns,'avg_word_length':avg_word_length}

# %%
output=pd.DataFrame()
output=output.append(data,ignore_index=True)
output.columns=['positive_score','negative_score','Polarity_Score','subjectiivity_score','avg_senetence_length','Percentage_of_Complex_words','Fog_Index','avg_no_of_words_per_sentence','complex_Word_Count','word_count','syllable_count','personal_pronouns','avg_word_length']
output
# Out:
# <ipython-input-5427-47d6873dceb2>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output=output.append(data,ignore_index=True)
#    positive_score  negative_score  Polarity_Score  subjectiivity_score  \
# 0            34.0            58.0        -0.26087            -0.023256
#
#    avg_senetence_length  Percentage_of_Complex_words  Fog_Index  \
# 0            162.380952                     0.356589  65.095017
#
#    avg_no_of_words_per_sentence  complex_Word_Count  word_count  \
# 0                     23.809524               368.0      1032.0
#
#    syllable_count  personal_pronouns  avg_word_length
# 0          2254.0                1.0         5.680233

# %%
# with open('output.csv', 'a') as f:#creating text file
#     output.to_csv(f, index=False, header=False)
# files.download('output.csv')
